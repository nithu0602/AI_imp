# %%
# !pip install tensorflow tensorflow-cpu opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\nithy\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-cpu in c:\users\nithy\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: opencv-python in c:\users\nithy\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: matplotlib in c:\users\nithy\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (63.4.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.10)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.9)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: packaging in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.55.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nithy\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nithy\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nithy\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nithy\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nithy\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nithy\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nithy\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\nithy\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\nithy\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nithy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nithy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nithy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\nithy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nithy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.18.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nithy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nithy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nithy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\nithy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.11)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nithy\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nithy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nithy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nithy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\nithy\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nithy\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# astunparse                    1.6.3
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.5.1
# bkcharts                      0.2
# black                         22.6.0
# bleach                        4.1.0
# bokeh                         2.4.3
# boto3                         1.24.28
# botocore                      1.27.28
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# cachetools                    5.3.0
# caer                          2.0.8
# certifi                       2022.9.14
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.5
# colorcet                      3.0.0
# comtypes                      1.1.10
# conda                         22.9.0
# conda-build                   3.22.0
# conda-content-trust           0.1.3
# conda-pack                    0.6.0
# conda-package-handling        1.9.0
# conda-repo-cli                1.0.20
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  37.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.32
# cytoolz                       0.11.0
# daal4py                       2021.6.0
# dask                          2022.7.0
# datashader                    0.14.1
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.4
# distributed                   2022.7.0
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# fastjsonschema                2.16.2
# filelock                      3.6.0
# flake8                        4.0.1
# Flask                         1.1.2
# flatbuffers                   23.5.9
# fonttools                     4.25.0
# fsspec                        2022.7.1
# future                        0.18.2
# gast                          0.4.0
# gensim                        4.1.2
# glob2                         0.7
# google-auth                   2.18.1
# google-auth-oauthlib          1.0.0
# google-pasta                  0.2.0
# greenlet                      1.1.1
# grpcio                        1.55.0
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.15.0
# hvplot                        0.8.0
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.19.3
# imagesize                     1.4.1
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.15.2
# ipython                       7.31.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jax                           0.4.10
# jdcal                         1.4.1
# jedi                          0.18.1
# jellyfish                     0.9.0
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.16.0
# jupyter                       1.0.0
# jupyter_client                7.3.4
# jupyter-console               6.4.3
# jupyter_core                  4.11.1
# jupyter-server                1.18.1
# jupyterlab                    3.4.4
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keras                         2.12.0
# keyring                       23.4.0
# kiwisolver                    1.4.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      16.0.0
# llvmlite                      0.38.0
# locket                        1.0.0
# lxml                          4.9.1
# lz4                           3.1.3
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.6
# mccabe                        0.6.1
# menuinst                      1.4.19
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# ml-dtypes                     0.1.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.3
# multipledispatch              0.6.0
# munkres                       1.1.4
# mypy                          0.991
# mypy-extensions               0.4.3
# navigator-updater             0.3.0
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.5.0
# nest-asyncio                  1.5.5
# networkx                      2.8.4
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.12
# numba                         0.55.1
# numexpr                       2.8.3
# numpy                         1.23.5
# numpydoc                      1.4.0
# oauthlib                      3.2.2
# olefile                       0.46
# opencv-contrib-python         4.7.0.68
# opencv-python                 4.7.0.72
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# packaging                     21.3
# pandas                        1.4.4
# pandocfilters                 1.5.0
# panel                         0.13.1
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathlib                       1.0.1
# pathspec                      0.9.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.2.2
# pkginfo                       1.8.2
# platformdirs                  2.5.2
# plotly                        5.9.0
# pluggy                        1.0.0
# poyo                          0.5.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      4.23.1
# psutil                        5.9.0
# ptyprocess                    0.7.0
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.8.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.8
# pycurl                        7.45.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.4.0
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.14.5
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.3.3
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2022.1
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         23.2.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.2.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# requests                      2.28.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# rope                          0.22.0
# rsa                           4.9
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.6.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20221004.171935
# scipy                         1.9.1
# Scrapy                        2.6.2
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    63.4.1
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.2.2
# spyder-kernels                2.2.1
# SQLAlchemy                    1.4.39
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.12.3
# tensorboard-data-server       0.7.0
# tensorflow                    2.12.0
# tensorflow-cpu                2.12.0
# tensorflow-estimator          2.12.0
# tensorflow-intel              2.12.0
# tensorflow-io-gcs-filesystem  0.31.0
# termcolor                     2.3.0
# terminado                     0.13.1
# testpath                      0.6.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.1
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typing_extensions             4.3.0
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       1.26.11
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.14.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.27.15
# yapf                          0.31.0
# zict                          2.1.0
# zipp                          3.8.0
# zope.interface                5.4.0

# %%
import tensorflow as tf

# %%
cpus = tf.config.experimental.list_physical_devices('CPU')

# %%
cpus
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
cpus = tf.config.experimental.list_physical_devices('CPU')
for cpu in cpus: 
    tf.config.experimental.set_memory_growth(cpu, True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10956\3864597104.py in <module>
#       1 cpus = tf.config.experimental.list_physical_devices('CPU')
#       2 for cpu in cpus:
# ----> 3     tf.config.experimental.set_memory_growth(cpu, True)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in set_memory_growth(device, enable)
#     733     RuntimeError: Runtime is already initialized.
#     734   """
# --> 735   context.context().set_memory_growth(device, enable)
#     736
#     737
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in set_memory_growth(self, dev, enable)
#    1660
#    1661     if dev.device_type != "GPU" and dev not in self._pluggable_devices:
# -> 1662       raise ValueError(
#    1663           "Cannot set memory growth on non-GPU and non-Pluggable devices")
#    1664
#
# ValueError: Cannot set memory growth on non-GPU and non-Pluggable devices

# %% [markdown]
# Removing dodgy images

# %%
import cv2
import imghdr #checks the file extension

# %%
# !rm -r data/sad/.ipynb_checkpoints
# Out:
# rm: cannot remove `data/sad/.ipynb_checkpoints': No such file or directory

# %%
import os
from matplotlib import pyplot as plt

# %%
data_dir = r"C:\Users\nithy\data"

# %%
for image_class in os.listdir(data_dir):
    for images in os.listdir( os.path.join(data_dir,image_class) ):
        print(images)
# Out:
# 05-12-21-happy-people.jpg
# 07-120104-happy_people_are_not_nice_people.jpg
# 1-2.jpg
# 1000_F_42220133_toAU6USGY9jVr2XJFLssfG00cSYIJ173.jpg
# 11-Habits-of-Truly-Happy-People.jpg
# 154006829.jpg
# 170404-happy-workers-feature.jpg
# 1902539.jpg
# 1902540.jpg
# 1902587.jpg
# 1920px-face-smile.svg_.png.jpg
# 1HEoLBLidT2u4mhJ0oiDgig.png
# 227-2271622_happy-people-business-team-celebrating-png.png
# 7-Habits-of-Happy-People-image.jpeg
# 7-principles-of-successful-and-happy-people.png
# 7Y57w0983emdERAoQylUHIGkoEk1cIFvPkXDbeA2lVA.jpg
# 8cxKy5g9i.jpg
# 960x0.jpg
# A_Sep20_14_1189155141.jpg
# bigstock-Portrait-Of-Smiling-Employees-272904928-min-scaled.jpg
# blog_image_20180219221810890.jpg
# brady-bunch-3.jpg
# e162ccda8ce0f197f8863f327add9233.jpg
# fiendship-concept-smiling-friends-communication-weekend-university-123724503.jpg
# friends-happy-190821-800x450.jpg
# GettyImages-565706549-949x534.jpg
# GettyImages-871518740-1024x707.jpg
# getty_152414899_97046097045006_68075.jpg
# getty_478389113_970647970450091_99776.jpg
# getty_494581822_130796.jpg
# getty_505175324_2000131020009280246_158016.jpg
# goup-happy-people-group-jumping-isolated-white-background-35582232.jpg
# group-of-happy-people-2.jpg
# habits-of-happy-people-cr3.jpg
# habits-of-happy-people.jpg
# habits-that-define-very-happy-people.jpg
# Happiness-Habits-10-Things-Happy-People-Do-Before-Bed.jpg
# happiness.jpg
# happinessa.jpg
# happy-girl-in-leaves.jpg
# happy-people-1024x768.jpeg
# happy-people-13772392.jpg
# happy-people-14410042.jpg
# happy-people-702x336.jpg
# Happy-people-800x533.jpg
# happy-people-black-and-white-720x360.jpg
# HAPPY-PEOPLE-CLUB-LOGO.jpg
# happy-people-group-fb.jpg
# Happy-people-raise-happy-kids-raise-yourself-first.jpg
# happy-people-vector-29209040.jpg
# happy-people-vector-839522.jpg
# happy-people.jpg
# happy-people21.jpg
# happy-people_1463241208.jpg
# happy-person.jpeg
# happy-woman-in-nature-at-sunset.jpg
# happypeople-1024x679.jpg
# HappyPeopleBanner.png
# Happy_People_Happy_Man.jpg
# hdptcar-fi-2.jpg
# how-happy-are-healthy-people.jpg
# How-to-Be-Happy_1200x628-facebook.jpg
# How_Happy_Are_People_at_Work.jpg
# hqdefault.jpg
# image16.jpeg
# image17.jpeg
# image18.jpeg
# image19.jpeg
# image20.jpeg
# image25.jpeg
# image26.jpeg
# images12.jpg
# images17.jpg
# images26.jpg
# images28.jpg
# images30.jpg
# images31.jpg
# images36.jpg
# images6.jpg
# iStock-1212931050.jpg
# jumping_for_joy_for_3_kinds_of_happy_people.jpg
# maxresdefault.jpg
# maxresdefault2.jpg
# MV5BMTM3ODM0NTQ1MF5BMl5BanBnXkFtZTcwMzAxMTM5OA._V1_.jp
olated-girl-crying-over-makeup-sad-person-concept-isolated-white-174239618.jpg
# Issue with image C:\Users\nithy\data\sad\iStock-174971863.jpg
# Issue with image C:\Users\nithy\data\sad\iStock_000001932580XSmall.jpg
# Issue with image C:\Users\nithy\data\sad\landscape-4209944_1280.jpg
# Issue with image C:\Users\nithy\data\sad\Make-someone-sad-happy.jpg
# Issue with image C:\Users\nithy\data\sad\maxresdefault.jpg
# Issue with image C:\Users\nithy\data\sad\maxresdefault2.jpg
# Issue with image C:\Users\nithy\data\sad\maxresdefault3.jpg
# Issue with image C:\Users\nithy\data\sad\maxresdefault4.jpg
# Issue with image C:\Users\nithy\data\sad\original.jpg
# Issue with image C:\Users\nithy\data\sad\pablo-varela-311608.jpg
# Issue with image C:\Users\nithy\data\sad\person-super-depressed.jpg
# Issue with image C:\Users\nithy\data\sad\running-mascara.jpg
# Issue with image C:\Users\nithy\data\sad\sad-big-SS.jpg
# Issue with image C:\Users\nithy\data\sad\sad-depressed-man.jpg
# Issue with image C:\Users\nithy\data\sad\sad-group-people-problems-17033671.jpg
# Issue with image C:\Users\nithy\data\sad\sad-human-figure-depression-concept-drawing-frank-ramspott.jpg
# Issue with image C:\Users\nithy\data\sad\sad-looking-man.jpg
# Issue with image C:\Users\nithy\data\sad\Sad-People-Bad-People-Luckie-1050x700.jpg
# Issue with image C:\Users\nithy\data\sad\sad-people-icon-2CCHXB2.jpg
# Issue with image C:\Users\nithy\data\sad\sad-people-png-favpng-XVec9sHvxbuQCQm0RmGgQx3bA.jpg
# Issue with image C:\Users\nithy\data\sad\sad-people-vector-2153909.jpg
# Issue with image C:\Users\nithy\data\sad\sad-people-vector-26812552.jpg
# Issue with image C:\Users\nithy\data\sad\sad-people.jpg
# Issue with image C:\Users\nithy\data\sad\sad-person-concept-vector-26538685.jpg
# Issue with image C:\Users\nithy\data\sad\sad-talks-for-sad-people-fb13.png
# Issue with image C:\Users\nithy\data\sad\sad-woman.jpg
# Issue with image C:\Users\nithy\data\sad\SAD.jpg
# Issue with image C:\Users\nithy\data\sad\sadness-inside-out-today-main-tease-191018.jpg
# Issue with image C:\Users\nithy\data\sad\sadness.jpg
# Issue with image C:\Users\nithy\data\sad\screen-shot-2014-07-31-at-6-09-12-pm.png
# Issue with image C:\Users\nithy\data\sad\smiling-man-crowd-sad-people-vector-58533122.jpg
# Issue with image C:\Users\nithy\data\sad\vh6to.jpg

# %% [markdown]
# Load the data

# %% [raw]
# tensorflow allows u to build a data pipeline. so u can scale out data

# %%
import numpy as np

# %%
data=tf.keras.utils.image_dataset_from_directory(data_dir,batch_size=8,image_size=(256,256))
# Out:
# Found 164 files belonging to 2 classes.

# %%
  data_iterator=data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %%
len(batch) # 2 parts to the batches. 
#1st is the img and next is labels. 
#Fitst is img loaded to memory as a numpy array.
# Out:
# 2

# %%
batch[0].shape
# Out:
# (8, 256, 256, 3)

# %%
batch[1] 
#sad=1
#happy=0
# Out:
# array([1, 0, 1, 0, 0, 0, 0, 0])

# %%
fig, ax = plt.subplots(ncols=6, figsize=(20,20))
for idx, img in enumerate(batch[0][:6]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# Preprocessing data

# %%
data=data.map(lambda x,y:(x/255,y)) #x=img and y=label

# %%
scaled_iterator=data.as_numpy_iterator()

# %%
b=scaled_iterator.next()

# %%
b[0].max()
# Out:
# 1.0

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(b[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(b[1][idx])

# %% [markdown]
# split data

# %%
len(data)
# Out:
# 21

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)

# %%
train_size+val_size+test_size
# Out:
# 21

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %%
len(test)
# Out:
# 2

# %% [markdown]
# Deep Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model=Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train datab

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 14/14 [==============================] - 22s 1s/step - loss: 0.6853 - accuracy: 0.6518 - val_loss: 0.6650 - val_accuracy: 0.7250
# Epoch 2/20
# 14/14 [==============================] - 18s 899ms/step - loss: 0.5761 - accuracy: 0.7143 - val_loss: 0.5956 - val_accuracy: 0.7500
# Epoch 3/20
# 14/14 [==============================] - 17s 871ms/step - loss: 0.5355 - accuracy: 0.7054 - val_loss: 0.4084 - val_accuracy: 0.8000
# Epoch 4/20
# 14/14 [==============================] - 16s 794ms/step - loss: 0.3815 - accuracy: 0.8393 - val_loss: 0.3132 - val_accuracy: 0.8500
# Epoch 5/20
# 14/14 [==============================] - 17s 907ms/step - loss: 0.3351 - accuracy: 0.8482 - val_loss: 0.2279 - val_accuracy: 0.9500
# Epoch 6/20
# 14/14 [==============================] - 18s 801ms/step - loss: 0.2503 - accuracy: 0.9196 - val_loss: 0.3652 - val_accuracy: 0.8750
# Epoch 7/20
# 14/14 [==============================] - 17s 808ms/step - loss: 0.1827 - accuracy: 0.9554 - val_loss: 0.1886 - val_accuracy: 0.9250
# Epoch 8/20
# 14/14 [==============================] - 16s 848ms/step - loss: 0.1260 - accuracy: 0.9911 - val_loss: 0.2347 - val_accuracy: 0.9250
# Epoch 9/20
# 14/14 [==============================] - 16s 794ms/step - loss: 0.1304 - accuracy: 0.9554 - val_loss: 0.1170 - val_accuracy: 0.9500
# Epoch 10/20
# 14/14 [==============================] - 17s 826ms/step - loss: 0.1352 - accuracy: 0.9643 - val_loss: 0.2173 - val_accuracy: 0.8500
# Epoch 11/20
# 14/14 [==============================] - 17s 855ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 0.9500
# Epoch 12/20
# 14/14 [==============================] - 16s 799ms/step - loss: 0.0502 - accuracy: 0.9821 - val_loss: 0.2030 - val_accuracy: 0.9500
# Epoch 13/20
# 14/14 [==============================] - 16s 785ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 14/20
# 14/14 [==============================] - 17s 861ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 15/20
# 14/14 [==============================] - 17s 854ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 16/20
# 14/14 [==============================] - 16s 786ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9750
# Epoch 17/20
# 14/14 [==============================] - 16s 780ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9750
# Epoch 18/20
# 14/14 [==============================] - 16s 784ms/step - loss: 0.0383 - accuracy: 0.9911 - val_loss: 0.0388 - val_accuracy: 0.9750
# Epoch 19/20
# 14/14 [==============================] - 17s 789ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 20/20
# 14/14 [==============================] - 16s 784ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000

# %% [markdown]
# Plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall:{ re.result().numpy()}, Acuracy: {acc.result().numpy()}')
# Out:
# Precision: 1.0, Recall:1.0, Acuracy: 1.0

# %% [markdown]
# Test

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r'C:\Users\nithy\Image classification\test\happy9.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
resize.shape
s=np.expand_dims(resize,0)
s.shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
yhat
# Out:
# array([[0.01019636]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Happy

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','happysadmodel.h5'))

# %%
new_model=load_model(os.path.join('models','happysadmodel.h5'))
